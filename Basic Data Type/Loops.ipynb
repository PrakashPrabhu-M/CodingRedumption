# %% [markdown]
# https://www.hackerrank.com/challenges/python-loops/problem

# %% [markdown]
# ![image.png](attachment:838be51f-6de1-4cff-b3ef-7c1d87b11e51.png)

# %%
n=int(input())

for i in range(n):
    print(i*i)
